# %% [markdown]
# # Perhitungan Skor RNN-IDS

# %% [markdown]
# ## Import All Necessary Libraries

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Load All the Data

# %%
df_pred = pd.read_csv('/home/apta/neuralnetwork-AD/rnn-apta/results/vector/part_1_Treatment_training_21_run6/result-lstm-tcp21-hl2-seq2-do0.2-oov3500-part_10_Treatment_testing_21.csv', 
                      names=['id', 'binary_error', 'b_mean', 'b_iqr', 'b_zscore', 'floatin_error', 'f_mean', 'f_iqr', 'f_zscore'])

df_truth = pd.read_csv('/home/apta/neuralnetwork-AD/rnn-apta/texts_retraining/texts_retraining_21/part_10_ground_truth.csv', 
                       encoding='ISO-8859-1')

# %%
df_pred.head()
# Out:
#                                       id  binary_error  b_mean  b_iqr  \
# 0  172.16.0.1-53186-192.168.10.50-21-tcp      0.361111       0      0
# 1  172.16.0.1-59534-192.168.10.50-21-tcp      0.206897       0      0
# 2  172.16.0.1-57412-192.168.10.50-21-tcp      0.371429       0      0
# 3  172.16.0.1-58576-192.168.10.50-21-tcp      0.351351       0      0
# 4  172.16.0.1-57616-192.168.10.50-21-tcp      0.459459       1      0
#
#    b_zscore  floatin_error  f_mean  f_iqr  f_zscore
# 0         0    2586.117647       0      0         0
# 1         0     673.333333       0      0         0
# 2         0    4550.727273       0      0         0
# 3         0    5552.125000       0      0         0
# 4         0   94011.657143       0      1         1

# %%
df_truth.head()
# Out:
#                                       ID        Label
# 0  172.16.0.1-53186-192.168.10.50-21-tcp  FTP-Patator
# 1  172.16.0.1-59534-192.168.10.50-21-tcp  FTP-Patator
# 2  172.16.0.1-57412-192.168.10.50-21-tcp  FTP-Patator
# 3  172.16.0.1-58576-192.168.10.50-21-tcp  FTP-Patator
# 4  172.16.0.1-57616-192.168.10.50-21-tcp  FTP-Patator

# %%
df_pred[['b_iqr']].value_counts()
# Out:
# b_iqr
# 0        538
# 1          6
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_pred[['b_iqr']].value_counts()
# Out:
# b_iqr
# 0        538
# 1          6
# Name: count, dtype: int64

# %%
df_pred[['b_zscore']].value_counts()
# Out:
# b_zscore
# 0           543
# 1             1
# Name: count, dtype: int64

# %%
df_truth.isnull().sum()
# Out:
# ID       0
# Label    0
# dtype: int64

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Convert the type of the data

# %%
df_truth['Label'].head()
# Out:
# 0    FTP-Patator
# 1    FTP-Patator
# 2    FTP-Patator
# 3    FTP-Patator
# 4    FTP-Patator
# Name: Label, dtype: object

# %% [markdown]
# ## Making Predictions

# %%
df_pred["id"]
# Out:
# 0         172.16.0.1-53186-192.168.10.50-21-tcp
# 1         172.16.0.1-59534-192.168.10.50-21-tcp
# 2         172.16.0.1-57412-192.168.10.50-21-tcp
# 3         172.16.0.1-58576-192.168.10.50-21-tcp
# 4         172.16.0.1-57616-192.168.10.50-21-tcp
#                          ...
# 539    192.168.10.15-53261-192.168.10.50-21-tcp
# 540    192.168.10.16-34924-192.168.10.50-21-tcp
# 541    192.168.10.16-50440-192.168.10.50-21-tcp
# 542      192.168.10.9-6170-192.168.10.50-21-tcp
# 543    192.168.10.51-60554-192.168.10.50-21-tcp
# Name: id, Length: 544, dtype: object

# %%
df_truth["ID"]

# df_truth[df_truth["id"] == "192.168.10.50-21-172.16.0.1-52120-tcp"]
# Out:
# 0         172.16.0.1-53186-192.168.10.50-21-tcp
# 1         172.16.0.1-59534-192.168.10.50-21-tcp
# 2         172.16.0.1-57412-192.168.10.50-21-tcp
# 3         172.16.0.1-58576-192.168.10.50-21-tcp
# 4         172.16.0.1-57616-192.168.10.50-21-tcp
#                          ...
# 539    192.168.10.15-53261-192.168.10.50-21-tcp
# 540    192.168.10.16-34924-192.168.10.50-21-tcp
# 541    192.168.10.16-50440-192.168.10.50-21-tcp
# 542      192.168.10.9-6170-192.168.10.50-21-tcp
# 543    192.168.10.51-60554-192.168.10.50-21-tcp
# Name: ID, Length: 544, dtype: object

# %%
# Convert 'Label' column to numeric: BENIGN -> 0, other -> 1
df_truth['Label'] = df_truth['Label'].apply(lambda x: 0 if x == 'BENIGN' else 1)

# %%
# df_pred["Label"] = np.where(df_pred["id"].isin(df_truth["id"]), 1, 0)

# Rename 'ID' to 'id' in df_truth
df_truth = df_truth.rename(columns={'ID': 'id'})

# Now merge and drop rows where the label is missing
df_pred = df_pred.merge(df_truth[['id', 'Label']], on='id', how='left')
df_pred = df_pred.dropna(subset=['Label'])

# %%
df_pred[df_pred['Label']==1]
# Out:
#                                         id  binary_error  b_mean  b_iqr  \
# 0    172.16.0.1-53186-192.168.10.50-21-tcp      0.361111       0      0
# 1    172.16.0.1-59534-192.168.10.50-21-tcp      0.206897       0      0
# 2    172.16.0.1-57412-192.168.10.50-21-tcp      0.371429       0      0
# 3    172.16.0.1-58576-192.168.10.50-21-tcp      0.351351       0      0
# 4    172.16.0.1-57616-192.168.10.50-21-tcp      0.459459       1      0
# ..                                     ...           ...     ...    ...
# 491  172.16.0.1-59398-192.168.10.50-21-tcp      0.305085       0      0
# 492  172.16.0.1-56664-192.168.10.50-21-tcp      0.343750       0      0
# 493  172.16.0.1-59184-192.168.10.50-21-tcp      0.393939       0      0
# 494  172.16.0.1-57960-192.168.10.50-21-tcp      0.313559       0      0
# 495  172.16.0.1-59542-192.168.10.50-21-tcp      0.129032       0      0
#
#      b_zscore  floatin_error  f_mean  f_iqr  f_zscore  Label
# 0           0    2586.117647       0      0         0      1
# 1           0     673.333333       0      0         0      1
# 2           0    4550.727273       0      0         0      1
# 3           0    5552.125000       0      0         0      1
# 4           0   94011.657143       0      1         1      1
# ..        ...            ...     ...    ...       ...    ...
# 491         0  133419.801724       0      1         1      1
# 492         0    1309.533333       0      0         0      1
# 493         0  149276.838710       1      1         1      1
# 494         0   10203.120690       0      0         0      1
# 495         0    1068.827586       0      0         0      1
#
# [496 rows x 10 columns]

# %%
df_pred[df_pred['Label']==0]
# Out:
#                                            id  binary_error  b_mean  b_iqr  \
# 496  192.168.10.15-57087-192.168.10.50-21-tcp      0.367816       0      0
# 497  192.168.10.14-54119-192.168.10.50-21-tcp      0.390805       0      0
# 498  192.168.10.12-53212-192.168.10.50-21-tcp      0.390805       0      0
# 499  192.168.10.12-35396-192.168.10.50-21-tcp      0.379310       0      0
# 500  192.168.10.12-59788-192.168.10.50-21-tcp      0.367816       0      0
# 501  192.168.10.14-54136-192.168.10.50-21-tcp      0.367816       0      0
# 502  192.168.10.14-54835-192.168.10.50-21-tcp      0.356322       0      0
# 503  192.168.10.17-55937-192.168.10.50-21-tcp      0.390805       0      0
# 504  192.168.10.51-36201-192.168.10.50-21-tcp      0.379310       0      0
# 505  192.168.10.12-59268-192.168.10.50-21-tcp      0.402299       0      0
# 506  192.168.10.15-54041-192.168.10.50-21-tcp      0.402299       0      0
# 507  192.168.10.17-52071-192.168.10.50-21-tcp      0.390805       0      0
# 508  192.168.10.19-59145-192.168.10.50-21-tcp      0.379310       0      0
# 509   192.168.10.8-52284-192.168.10.50-21-tcp      0.402299       0      0
# 510  192.168.10.16-48994-192.168.10.50-21-tcp      0.367816       0      0
# 511  192.168.10.12-57122-192.168.10.50-21-tcp      0.390805       0      0
# 512  192.168.10.17-53700-192.168.10.50-21-tcp      0.390805       0      0
# 513  192.168.10.51-56015-192.168.10.50-21-tcp      0.367816       0      0
# 514  192.168.10.16-49018-192.168.10.50-21-tcp      0.390805       0      0
# 515  192.168.10.12-45876-192.168.10.50-21-tcp      0.390805       0      0
# 516   192.168.10.5-49222-192.168.10.50-21-tcp      0.402299       0      0
# 517  192.168.10.17-51239-192.168.10.50-21-tcp      0.379310       0      0
# 518  192.168.10.51-57073-192.168.10.50-21-tcp      0.402299       0      0
# 519   192.168.10.8-57484-192.168.10.50-21-tcp      0.402299       0      0
# 520  192.168.10.25-63177-192.168.10.50-21-tcp      0.379310       0      0
# 521   192.168.10.5-64755-192.168.10.50-21-tcp      0.379310       0      0
# 522   192.168.10.8-55775-192.168.10.50-21-tcp      0.379310       0      0
# 523  192.168.10.51-53596-192.168.10.50-21-tcp      0.379310       0      0
# 524  192.168.10.51-52661-192.168.10.50-21-tcp      0.379310       0      0
# 525  192.168.10.14-50913-192.168.10.50-21-tcp      0.379310       0      0
# 526  192.168.10.14-54304-192.168.10.50-21-tcp      0.402299       0      0
# 527    192.168.10.9-3568-192.168.10.50-21-tcp      0.356322       0      0
# 528   192.168.10.5-55157-192.168.10.50-21-tcp      0.390805       0      0
# 529   192.168.10.9-62342-192.168.10.50-21-tcp      0.390805       0      0
# 530   192.168.10.5-65404-192.168.10.50-21-tcp      0.390805       0      0
# 531  192.168.10.19-58039-192.168.10.50-21-tcp      0.367816       0      0
# 532    192.168.10.9-6422-192.168.10.50-21-tcp      0.367816       0      0
# 533    192.168.10.9-8913-192.168.10.50-21-tcp      0.367816       0      0
# 534  192.168.10.19-58038-192.168.10.50-21-tcp      0.379310       0      0
# 535  192.168.10.14-59525-192.168.10.50-21-tcp      0.390805       0      0
# 536  192.168.10.14-58328-192.168.10.50-21-tcp      0.390805       0      0
# 537  192.168.10.25-59292-192.168.10.50-21-tcp      0.379310       0      0
# 538  192.168.10.12-54112-192.168.10.50-21-tcp      0.367816       0      0
# 539  192.168.10.15-53261-192.168.10.50-21-tcp      0.390805       0      0
# 540  192.168.10.16-34924-192.168.10.50-21-tcp      0.379310       0      0
# 541  192.168.10.16-50440-192.168.10.50-21-tcp      0.367816       0      0
# 542    192.168.10.9-6170-192.168.10.50-21-tcp      0.367816       0      0
# 543  192.168.10.51-60554-192.168.10.50-21-tcp      0.390805       0      0
#
#      b_zscore  floatin_error  f_mean  f_iqr  f_zscore  Label
# 496         0    3469.576471       0      0         0      0
# 497         0    3553.376471       0      0         0      0
# 498         0    7111.870588       0      0         0      0
# 499         0    4056.905882       0      0         0      0
# 500         0    7080.235294       0      0         0      0
# 501         0    4078.870588       0      0         0      0
# 502         0    2174.588235       0      0         0      0
# 503         0    4434.658824       0      0         0      0
# 504         0    3718.458824       0      0         0      0
# 505         0    7167.294118       0      0         0      0
# 506         0    5955.235294       0      0         0      0
# 507         0    4352.941176       0      0         0      0
# 508         0    5962.576471       0      0         0      0
# 509         0    6048.341176       0      0         0      0
# 510         0    3412.600000       0      0         0      0
# 511         0    3277.494118       0      0         0      0
# 512         0    3370.282353       0      0         0      0
# 513         0    2694.752941       0      0         0      0
# 514         0    3984.235294       0      0         0      0
# 515         0    5819.858824       0      0         0      0
# 516         0    3250.823529       0      0         0      0
# 517         0    7514.047059       0      0         0      0
# 518         0    6363.070588       0      0         0      0
# 519         0    5611.352941       0      0         0      0
# 520         0    5522.329412       0      0         0      0
# 521         0    3819.517647       0      0         0      0
# 522         0    5841.329412       0      0         0      0
# 523         0    4251.517647       0      0         0      0
# 524         0    4301.764706       0      0         0      0
# 525         0    3259.094118       0      0         0      0
# 526         0    6269.588235       0      0         0      0
# 527         0    5088.470588       0      0         0      0
# 528         0    4896.988235       0      0         0      0
# 529         0    6955.811765       0      0         0      0
# 530         0    3777.305882       0      0         0      0
# 531         0    4340.588235       0      0         0      0
# 532         0    9876.494118       0      0         0      0
# 533         0    2278.776471       0      0         0      0
# 534         0    2412.117647       0      0         0      0
# 535         0    3757.905882       0      0         0      0
# 536         0    7532.847059       0      0         0      0
# 537         0    6559.000000       0      0         0      0
# 538         0    2861.682353       0      0         0      0
# 539         0    4312.388235       0      0         0      0
# 540         0    2665.905882       0      0         0      0
# 541         0    4750.435294       0      0         0      0
# 542         0    5457.564706       0      0         0      0
# 543         0    5269.835294       0      0         0      0

# %%
df_pred
# Out:
#                                            id  binary_error  b_mean  b_iqr  \
# 0       172.16.0.1-53186-192.168.10.50-21-tcp      0.361111       0      0
# 1       172.16.0.1-59534-192.168.10.50-21-tcp      0.206897       0      0
# 2       172.16.0.1-57412-192.168.10.50-21-tcp      0.371429       0      0
# 3       172.16.0.1-58576-192.168.10.50-21-tcp      0.351351       0      0
# 4       172.16.0.1-57616-192.168.10.50-21-tcp      0.459459       1      0
# ..                                        ...           ...     ...    ...
# 539  192.168.10.15-53261-192.168.10.50-21-tcp      0.390805       0      0
# 540  192.168.10.16-34924-192.168.10.50-21-tcp      0.379310       0      0
# 541  192.168.10.16-50440-192.168.10.50-21-tcp      0.367816       0      0
# 542    192.168.10.9-6170-192.168.10.50-21-tcp      0.367816       0      0
# 543  192.168.10.51-60554-192.168.10.50-21-tcp      0.390805       0      0
#
#      b_zscore  floatin_error  f_mean  f_iqr  f_zscore  Label
# 0           0    2586.117647       0      0         0      1
# 1           0     673.333333       0      0         0      1
# 2           0    4550.727273       0      0         0      1
# 3           0    5552.125000       0      0         0      1
# 4           0   94011.657143       0      1         1      1
# ..        ...            ...     ...    ...       ...    ...
# 539         0    4312.388235       0      0         0      0
# 540         0    2665.905882       0      0         0      0
# 541         0    4750.435294       0      0         0      0
# 542         0    5457.564706       0      0         0      0
# 543         0    5269.835294       0      0         0      0
#
# [544 rows x 10 columns]

# %%
df_pred[['Label']].value_counts()
# Out:
# Label
# 1        496
# 0         48
# Name: count, dtype: int64

# %%
import os
# Define the directory path
dir_path = '../mcnemar/ftp'

# Check if the directory exists, and if not, create it
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

df_temp = df_pred[['id', 'b_mean','b_iqr', 'b_zscore', 'f_zscore', 'f_mean','f_iqr' ]]
df_temp.to_csv(os.path.join(dir_path, 'pred_0.0.csv'))

# %% [markdown]
# ## Calculating Score

# %%
threshold = ['b_mean', 'b_iqr', 'b_zscore']
threshold_2 = ['f_mean', 'f_iqr', 'f_zscore']

methods = ['binary', 'floating']

# %%
df_pred[['b_zscore']]
# Out:
#      b_zscore
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 539         0
# 540         0
# 541         0
# 542         0
# 543         0
#
# [544 rows x 1 columns]

# %% [markdown]
# ### Detection Rate

# %%
from sklearn.metrics import recall_score

score = dict()
score['Detection Rate'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            acc = recall_score(df_pred['Label'], df_pred[i])
            score['Detection Rate'][i] = acc
            print(f'Recall-Binary-{i}: {acc}')
    else:
        for i in threshold_2:
            acc = recall_score(df_pred['Label'], df_pred[i])
            score['Detection Rate'][i] = acc
            print(f'Recall-Floating-{i}: {acc}')
# Out:
# Recall-Binary-b_mean: 0.10887096774193548
# Recall-Binary-b_iqr: 0.012096774193548387
# Recall-Binary-b_zscore: 0.0020161290322580645
# Recall-Floating-f_mean: 0.12903225806451613
# Recall-Floating-f_iqr: 0.23790322580645162
# Recall-Floating-f_zscore: 0.35080645161290325

# %% [markdown]
# ### Confussion Matrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

for method in methods:
    if method == 'binary':
        for i in threshold:
            conf_matrix = confusion_matrix(df_pred['Label'], df_pred[i])
            cm_display = ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels=['Benign', 'Anomaly'])
            cm_display.plot()
            plt.title(f'Binary - {i.strip()}')
            plt.show()
    else:
        for i in threshold_2:
            conf_matrix = confusion_matrix(df_pred['Label'], df_pred[i])
            cm_display = ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels=['Benign', 'Anomaly'])
            cm_display.plot()
            plt.title(f'Floating - {i.strip()}')
            plt.show()

# %% [markdown]
# ### F2-Score

# %%
score['F2 Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i]).ravel()
            f2 = ((1+2**2)*tp)/((1+2**2)*tp+2**2*fn+fp)
            score['F2 Score'][i] = f2
            print(f'F2-Binary-{i}: {f2}')
    else:
        for i in threshold_2:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i]).ravel()
            f2 = ((1+2**2)*tp)/((1+2**2)*tp+2**2*fn+fp)
            score['F2 Score'][i] = f2
            print(f'F2-Floating-{i}: {f2}')
# Out:
# F2-Binary-b_mean: 0.1324828263002944
# F2-Binary-b_iqr: 0.01507537688442211
# F2-Binary-b_zscore: 0.0025188916876574307
# F2-Floating-f_mean: 0.15625
# F2-Floating-f_iqr: 0.28068506184586106
# F2-Floating-f_zscore: 0.4031510658016682

# %% [markdown]
# ### FPR Score

# %%
score['FPR Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i]).ravel()
            fpr = fp/(fp+tn)
            score['FPR Score'][i] = fpr
            print(f'FPR-Binary-{i}: {fpr}')
    else:
        for i in threshold_2:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i]).ravel()
            fpr = fp/(fp+tn)
            score['FPR Score'][i] = fpr
            print(f'FPR-Floating-{i}: {fpr}')
# Out:
# FPR-Binary-b_mean: 0.0
# FPR-Binary-b_iqr: 0.0
# FPR-Binary-b_zscore: 0.0
# FPR-Floating-f_mean: 0.0
# FPR-Floating-f_iqr: 0.0
# FPR-Floating-f_zscore: 0.0

# %%
from sklearn.metrics import accuracy_score

score['Accuracy Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            acc = accuracy_score(df_pred['Label'], df_pred[i])
            score['Accuracy Score'][i] = acc
            print(f'Accuracy-Binary-{i}: {acc}')
    else:
        for i in threshold_2:
            acc = accuracy_score(df_pred['Label'], df_pred[i])
            score['Accuracy Score'][i] = acc
            print(f'Accuracy-Floating-{i}: {acc}')
# Out:
# Accuracy-Binary-b_mean: 0.1875
# Accuracy-Binary-b_iqr: 0.09926470588235294
# Accuracy-Binary-b_zscore: 0.0900735294117647
# Accuracy-Floating-f_mean: 0.20588235294117646
# Accuracy-Floating-f_iqr: 0.30514705882352944
# Accuracy-Floating-f_zscore: 0.40808823529411764

# %%
df_score = pd.DataFrame.from_dict(score)
df_score
# Out:
#           Detection Rate  F2 Score  FPR Score  Accuracy Score
# b_mean          0.108871  0.132483        0.0        0.187500
# b_iqr           0.012097  0.015075        0.0        0.099265
# b_zscore        0.002016  0.002519        0.0        0.090074
# f_mean          0.129032  0.156250        0.0        0.205882
# f_iqr           0.237903  0.280685        0.0        0.305147
# f_zscore        0.350806  0.403151        0.0        0.408088

# %%
df_score.to_excel('score_ftp_0.0.xlsx')

# %%
# %pip install openpyxl
