# %% [markdown]
# # Perhitungan Skor RNN-IDS

# %% [markdown]
# ## Import All Necessary Libraries

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Load All the Data

# %%
df_pred = pd.read_csv('/home/apta/neuralnetwork-AD/rnn-apta/results/vector/noisy_port-80_percentage-0.0.pcap/result-lstm-tcp80-hl2-seq4-do0.2-oov2500-Friday-WorkingHours_testing_80.csv', 
                      names=['id', 'binary_error', 'b_mean', 'b_iqr', 'b_zscore', 'floatin_error', 'f_mean', 'f_iqr', 'f_zscore'])

df_truth = pd.read_csv('/home/apta/CIC-IDS-2017/CSVs/TrafficLabelling/Friday-WorkingHours.pcap_ISCX.csv', 
                       encoding='ISO-8859-1')

# %%
df_pred.head()
# Out:
#                                         id  binary_error  b_mean  b_iqr  \
# 0   192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# 1  192.168.10.9-8694-172.217.10.238-80-tcp      0.222480       1      1
# 2   192.168.10.5-54842-172.82.206.1-80-tcp      0.093243       0      1
# 3   192.168.10.9-8843-52.84.143.147-80-tcp      0.211299       1      1
# 4     192.168.10.9-8820-72.21.91.29-80-tcp      0.208909       1      1
#
#    b_zscore  floatin_error  f_mean  f_iqr  f_zscore
# 0         0   52746.931697       0      0         0
# 1         1  152776.800931       0      0         0
# 2         0   59590.374661       0      0         0
# 3         1  153303.661748       0      0         0
# 4         1  147939.417565       0      0         0

# %%
df_truth.head()
# Out:
#                                    Flow ID       Source IP   Source Port  \
# 0  192.168.10.5-104.16.207.165-54865-443-6  104.16.207.165           443
# 1    192.168.10.5-104.16.28.216-55054-80-6   104.16.28.216            80
# 2    192.168.10.5-104.16.28.216-55055-80-6   104.16.28.216            80
# 3  192.168.10.16-104.17.241.25-46236-443-6   104.17.241.25           443
# 4  192.168.10.5-104.19.196.102-54863-443-6  104.19.196.102           443
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0    192.168.10.5              54865          6  7/7/2017 3:30
# 1    192.168.10.5              55054          6  7/7/2017 3:30
# 2    192.168.10.5              55055          6  7/7/2017 3:30
# 3   192.168.10.16              46236          6  7/7/2017 3:30
# 4    192.168.10.5              54863          6  7/7/2017 3:30
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# 0               3                   2                        0  ...
# 1             109                   1                        1  ...
# 2              52                   1                        1  ...
# 3              34                   1                        1  ...
# 4               3                   2                        0  ...
#
#     min_seg_size_forward  Active Mean   Active Std   Active Max   Active Min  \
# 0                     20          0.0          0.0          0.0          0.0
# 1                     20          0.0          0.0          0.0          0.0
# 2                     20          0.0          0.0          0.0          0.0
# 3                     20          0.0          0.0          0.0          0.0
# 4                     20          0.0          0.0          0.0          0.0
#
#    Idle Mean   Idle Std   Idle Max   Idle Min   Label
# 0        0.0        0.0        0.0        0.0  BENIGN
# 1        0.0        0.0        0.0        0.0  BENIGN
# 2        0.0        0.0        0.0        0.0  BENIGN
# 3        0.0        0.0        0.0        0.0  BENIGN
# 4        0.0        0.0        0.0        0.0  BENIGN
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_truth[[' Label']].value_counts()
# Out:
#  Label
# BENIGN      414322
# PortScan    158930
# DDoS        128027
# Bot           1966
# Name: count, dtype: int64

# %%
df_pred[['b_iqr']].value_counts()
# Out:
# b_iqr
# 1        69864
# 0         3409
# Name: count, dtype: int64

# %%
df_pred[['b_zscore']].value_counts()
# Out:
# b_zscore
# 1           69413
# 0            3860
# Name: count, dtype: int64

# %%
df_truth.isnull().sum()
# Out:
# Flow ID              0
#  Source IP           0
#  Source Port         0
#  Destination IP      0
#  Destination Port    0
#                     ..
# Idle Mean            0
#  Idle Std            0
#  Idle Max            0
#  Idle Min            0
#  Label               0
# Length: 85, dtype: int64

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Convert the type of the data

# %%
df_truth.columns = df_truth.columns.str.strip()  # remove leading/trailing spaces
df_truth.columns = df_truth.columns.str.replace(' ', '_')  # optional: make them easier to type

df_truth['Source_Port'] = pd.to_numeric(df_truth['Source_Port'], errors='coerce')
df_truth['Destination_Port'] = pd.to_numeric(df_truth['Destination_Port'], errors='coerce')

# Optionally: drop rows with NaN in these columns
df_truth.dropna(subset=['Source_Port', 'Destination_Port'], inplace=True)

# Filter to only include rows where either port is 80
df_truth = df_truth[(df_truth['Source_Port'] == 80) | (df_truth['Destination_Port'] == 80)]

# Now you can safely convert to int
df_truth['Source_Port'] = df_truth['Source_Port'].astype(int)
df_truth['Destination_Port'] = df_truth['Destination_Port'].astype(int)


df_truth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 220417 entries, 1 to 703236
# Data columns (total 85 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Flow_ID                      220417 non-null  object
#  1   Source_IP                    220417 non-null  object
#  2   Source_Port                  220417 non-null  int64
#  3   Destination_IP               220417 non-null  object
#  4   Destination_Port             220417 non-null  int64
#  5   Protocol                     220417 non-null  int64
#  6   Timestamp                    220417 non-null  object
#  7   Flow_Duration                220417 non-null  int64
#  8   Total_Fwd_Packets            220417 non-null  int64
#  9   Total_Backward_Packets       220417 non-null  int64
#  10  Total_Length_of_Fwd_Packets  220417 non-null  int64
#  11  Total_Length_of_Bwd_Packets  220417 non-null  float64
#  12  Fwd_Packet_Length_Max        220417 non-null  int64
#  13  Fwd_Packet_Length_Min        220417 non-null  int64
#  14  Fwd_Packet_Length_Mean       220417 non-null  float64
#  15  Fwd_Packet_Length_Std        220417 non-null  float64
#  16  Bwd_Packet_Length_Max        220417 non-null  int64
#  17  Bwd_Packet_Length_Min        220417 non-null  int64
#  18  Bwd_Packet_Length_Mean       220417 non-null  float64
#  19  Bwd_Packet_Length_Std        220417 non-null  float64
#  20  Flow_Bytes/s                 220409 non-null  float64
#  21  Flow_Packets/s               220417 non-null  float64
#  22  Flow_IAT_Mean                220417 non-null  float64
#  23  Flow_IAT_Std                 220417 non-null  float64
#  24  Flow_IAT_Max                 220417 non-null  float64
#  25  Flow_IAT_Min                 220417 non-null  float64
#  26  Fwd_IAT_Total                220417 non-null  float64
#  27  Fwd_IAT_Mean                 220417 non-null  float64
#  28  Fwd_IAT_Std                  220417 non-null  float64
#  29  Fwd_IAT_Max                  220417 non-null  float64
#  30  Fwd_IAT_Min                  220417 non-null  float64
#  31  Bwd_IAT_Total                220417 non-null  float64
#  32  Bwd_IAT_Mean                 220417 non-null  float64
#  33  Bwd_IAT_Std                  220417 non-null  float64
#  34  Bwd_IAT_Max                  220417 non-null  float64
#  35  Bwd_IAT_Min                  220417 non-null  float64
#  36  Fwd_PSH_Flags                220417 non-null  int64
#  37  Bwd_PSH_Flags                220417 non-null  int64
#  38  Fwd_URG_Flags                220417 non-null  int64
#  39  Bwd_URG_Flags                220417 non-null  int64
#  40  Fwd_Header_Length            220417 non-null  int64
#  41  Bwd_Header_Length            220417 non-null  int64
#  42  Fwd_Packets/s                220417 non-null  float64
#  43  Bwd_Packets/s                220417 non-null  float64
#  44  Min_Packet_Length            220417 non-null  int64
#  45  Max_Packet_Length            220417 non-null  int64
#  46  Packet_Length_Mean           220417 non-null  float64
#  47  Packet_Length_Std            220417 non-null  float64
#  48  Packet_Length_Variance       220417 non-null  float64
#  49  FIN_Flag_Count               220417 non-null  int64
#  50  SYN_Flag_Count               220417 non-null  int64
#  51  RST_Flag_Count               220417 non-null  int64
#  52  PSH_Flag_Count               220417 non-null  int64
#  53  ACK_Flag_Count               220417 non-null  int64
#  54  URG_Flag_Count               220417 non-null  int64
#  55  CWE_Flag_Count               220417 non-null  int64
#  56  ECE_Flag_Count               220417 non-null  int64
#  57  Down/Up_Ratio                220417 non-null  int64
#  58  Average_Packet_Size          220417 non-null  float64
#  59  Avg_Fwd_Segment_Size         220417 non-null  float64
#  60  Avg_Bwd_Segment_Size         220417 non-null  float64
#  61  Fwd_Header_Length.1          220417 non-null  int64
#  62  Fwd_Avg_Bytes/Bulk           220417 non-null  int64
#  63  Fwd_Avg_Packets/Bulk         220417 non-null  int64
#  64  Fwd_Avg_Bulk_Rate            220417 non-null  int64
#  65  Bwd_Avg_Bytes/Bulk           220417 non-null  int64
#  66  Bwd_Avg_Packets/Bulk         220417 non-null  int64
#  67  Bwd_Avg_Bulk_Rate            220417 non-null  int64
#  68  Subflow_Fwd_Packets          220417 non-null  int64
#  69  Subflow_Fwd_Bytes            220417 non-null  int64
#  70  Subflow_Bwd_Packets          220417 non-null  int64
#  71  Subflow_Bwd_Bytes            220417 non-null  int64
#  72  Init_Win_bytes_forward       220417 non-null  int64
#  73  Init_Win_bytes_backward      220417 non-null  int64
#  74  act_data_pkt_fwd             220417 non-null  int64
#  75  min_seg_size_forward         220417 non-null  int64
#  76  Active_Mean                  220417 non-null  float64
#  77  Active_Std                   220417 non-null  float64
#  78  Active_Max                   220417 non-null  float64
#  79  Active_Min                   220417 non-null  float64
#  80  Idle_Mean                    220417 non-null  float64
#  81  Idle_Std                     220417 non-null  float64
#  82  Idle_Max                     220417 non-null  float64
#  83  Idle_Min                     220417 non-null  float64
#  84  Label                        220417 non-null  object
# dtypes: float64(37), int64(43), object(5)
# memory usage: 144.6+ MB

# %%
df_truth['Label'].value_counts()
# Out:
# Label
# DDoS        128027
# BENIGN       92017
# PortScan       373
# Name: count, dtype: int64

# %%
df_truth['Label'].head()
# Out:
# 1     BENIGN
# 2     BENIGN
# 14    BENIGN
# 26    BENIGN
# 39    BENIGN
# Name: Label, dtype: object

# %%
df_truth['Source_Port'] = df_truth['Source_Port'].astype(str)
df_truth['Destination_Port'] = df_truth['Destination_Port'].astype(str)

df_truth['Protocol'] = pd.to_numeric(df_truth['Protocol'], errors='coerce')  
df_truth.dropna(subset=['Protocol'], inplace=True)                      
df_truth['Protocol'] = df_truth['Protocol'].astype(int).astype(str)         

protocol_map = {
    '6': 'tcp',
    '17': 'udp',
    '1': 'icmp',
    '0': 'other'  # fallback or unknown
}

# Convert 'Protocol' number to string using the mapping
def map_protocol(protocol):
    return protocol_map.get(protocol, 'other')

# Apply the conversion for 'Protocol' and concatenate the 'id'
df_truth['id'] = df_truth[['Source_IP', 'Source_Port', 'Destination_IP', 'Destination_Port', 'Protocol']]\
    .astype(str).apply(lambda row: "-".join([row[0], row[1], row[2], row[3], map_protocol(row[4])]), axis=1)
# Out:
# /tmp/ipykernel_348552/691346611.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   .astype(str).apply(lambda row: "-".join([row[0], row[1], row[2], row[3], map_protocol(row[4])]), axis=1)

# %% [markdown]
# ## Making Predictions

# %%
df_pred["id"]
# Out:
# 0         192.168.10.5-54842-172.82.206.1-80-tcp
# 1        192.168.10.9-8694-172.217.10.238-80-tcp
# 2         192.168.10.5-54842-172.82.206.1-80-tcp
# 3         192.168.10.9-8843-52.84.143.147-80-tcp
# 4           192.168.10.9-8820-72.21.91.29-80-tcp
#                           ...
# 73268    192.168.10.15-53989-23.52.155.27-80-tcp
# 73269    192.168.10.15-53993-23.52.155.27-80-tcp
# 73270    192.168.10.15-53994-23.52.155.27-80-tcp
# 73271    192.168.10.15-53990-23.52.155.27-80-tcp
# 73272     192.168.10.14-53233-72.21.91.29-80-tcp
# Name: id, Length: 73273, dtype: object

# %%
df_truth["id"]
# Out:
# 1           104.16.28.216-80-192.168.10.5-55054-tcp
# 2           104.16.28.216-80-192.168.10.5-55055-tcp
# 14         104.97.140.32-80-192.168.10.16-36206-tcp
# 26         151.101.0.249-80-192.168.10.16-43248-tcp
# 39        152.163.66.165-80-192.168.10.16-60350-tcp
#                             ...
# 702971      192.168.10.15-53994-23.52.155.27-80-tcp
# 702975      192.168.10.15-53983-23.52.155.27-80-tcp
# 702979     63.144.176.10-80-192.168.10.14-53128-tcp
# 702981       72.21.91.29-80-192.168.10.14-53142-tcp
# 703236       192.168.10.14-53233-72.21.91.29-80-tcp
# Name: id, Length: 220417, dtype: object

# %%
# Convert 'Label' column to numeric: BENIGN -> 0, other -> 1
df_truth['Label'] = df_truth['Label'].apply(lambda x: 0 if x == 'BENIGN' else 1)

# %%
# df_pred["Label"] = np.where(df_pred["id"].isin(df_truth["id"]), 1, 0)

df_pred = df_pred.merge(df_truth[['id', 'Label']], on='id', how='left')
df_pred = df_pred.dropna(subset=['Label'])

# %%
# df_pred[df_pred['Label'] == 1].to_csv('filtered_predictions-1-80-friday.csv', index=False)

df_pred[df_pred['Label']==1]
# Out:
#                                            id  binary_error  b_mean  b_iqr  \
# 5782    172.16.0.1-49533-192.168.10.50-80-tcp      0.411765       1      1
# 5783    172.16.0.1-49533-192.168.10.50-80-tcp      0.411765       1      1
# 5784    172.16.0.1-49533-192.168.10.50-80-tcp      0.411765       1      1
# 5785    172.16.0.1-49533-192.168.10.50-80-tcp      0.411765       1      1
# 5786    172.16.0.1-49534-192.168.10.50-80-tcp      0.411765       1      1
# ...                                       ...           ...     ...    ...
# 158227  172.16.0.1-54599-192.168.10.50-80-tcp      0.513514       1      1
# 158228  172.16.0.1-54599-192.168.10.50-80-tcp      0.513514       1      1
# 158229  172.16.0.1-54599-192.168.10.50-80-tcp      0.513514       1      1
# 184420  172.16.0.1-40504-192.168.10.50-80-tcp      0.221429       1      1
# 184421  172.16.0.1-40504-192.168.10.50-80-tcp      0.221429       1      1
#
#         b_zscore  floatin_error  f_mean  f_iqr  f_zscore  Label
# 5782           1  937132.923077       1      1         1      1
# 5783           1  937132.923077       1      1         1      1
# 5784           1  937132.923077       1      1         1      1
# 5785           1  937132.923077       1      1         1      1
# 5786           1  937132.923077       1      1         1      1
# ...          ...            ...     ...    ...       ...    ...
# 158227         1  824036.606061       1      1         1      1
# 158228         1  824036.606061       1      1         1      1
# 158229         1  824036.606061       1      1         1      1
# 184420         1  136144.771552       0      0         0      1
# 184421         1  136144.771552       0      0         0      1
#
# [128654 rows x 10 columns]

# %%
# df_pred[df_pred['Label'] == 0].to_csv('filtered_predictions-0-80-friday.csv', index=False)

df_pred[df_pred['Label']==0]
# Out:
#                                              id  binary_error  b_mean  b_iqr  \
# 0        192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# 1        192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# 2        192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# 3        192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# 4        192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# ...                                         ...           ...     ...    ...
# 185686  192.168.10.15-53993-23.52.155.27-80-tcp      0.214953       1      1
# 185687  192.168.10.15-53994-23.52.155.27-80-tcp      0.214953       1      1
# 185688  192.168.10.15-53994-23.52.155.27-80-tcp      0.214953       1      1
# 185689  192.168.10.15-53990-23.52.155.27-80-tcp      0.214953       1      1
# 185690   192.168.10.14-53233-72.21.91.29-80-tcp      0.210773       1      1
#
#         b_zscore  floatin_error  f_mean  f_iqr  f_zscore  Label
# 0              0   52746.931697       0      0         0      0
# 1              0   52746.931697       0      0         0      0
# 2              0   52746.931697       0      0         0      0
# 3              0   52746.931697       0      0         0      0
# 4              0   52746.931697       0      0         0      0
# ...          ...            ...     ...    ...       ...    ...
# 185686         1  149635.261792       0      0         0      0
# 185687         1  149635.261792       0      0         0      0
# 185688         1  149635.261792       0      0         0      0
# 185689         1  149635.261792       0      0         0      0
# 185690         1  151263.328605       0      0         0      0
#
# [57037 rows x 10 columns]

# %%
df_pred
# Out:
#                                              id  binary_error  b_mean  b_iqr  \
# 0        192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# 1        192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# 2        192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# 3        192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# 4        192.168.10.5-54842-172.82.206.1-80-tcp      0.086935       0      0
# ...                                         ...           ...     ...    ...
# 185686  192.168.10.15-53993-23.52.155.27-80-tcp      0.214953       1      1
# 185687  192.168.10.15-53994-23.52.155.27-80-tcp      0.214953       1      1
# 185688  192.168.10.15-53994-23.52.155.27-80-tcp      0.214953       1      1
# 185689  192.168.10.15-53990-23.52.155.27-80-tcp      0.214953       1      1
# 185690   192.168.10.14-53233-72.21.91.29-80-tcp      0.210773       1      1
#
#         b_zscore  floatin_error  f_mean  f_iqr  f_zscore  Label
# 0              0   52746.931697       0      0         0      0
# 1              0   52746.931697       0      0         0      0
# 2              0   52746.931697       0      0         0      0
# 3              0   52746.931697       0      0         0      0
# 4              0   52746.931697       0      0         0      0
# ...          ...            ...     ...    ...       ...    ...
# 185686         1  149635.261792       0      0         0      0
# 185687         1  149635.261792       0      0         0      0
# 185688         1  149635.261792       0      0         0      0
# 185689         1  149635.261792       0      0         0      0
# 185690         1  151263.328605       0      0         0      0
#
# [185691 rows x 10 columns]

# %%
df_pred[['Label']].value_counts()
# Out:
# Label
# 1        128654
# 0         57037
# Name: count, dtype: int64

# %%
import os
# Define the directory path
dir_path = '../mcnemar/http'

# Check if the directory exists, and if not, create it
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

df_temp = df_pred[['id', 'b_mean','b_iqr', 'b_zscore', 'f_zscore', 'f_mean','f_iqr' ]]
df_temp.to_csv(os.path.join(dir_path, 'pred_0.0.csv'))

# %% [markdown]
# ## Calculating Score

# %%
threshold = ['b_mean', 'b_iqr', 'b_zscore']
threshold_2 = ['f_mean', 'f_iqr', 'f_zscore']

methods = ['binary', 'floating']

# %%
df_pred[['b_zscore']]
# Out:
#         b_zscore
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 185686         1
# 185687         1
# 185688         1
# 185689         1
# 185690         1
#
# [185691 rows x 1 columns]

# %% [markdown]
# ### Detection Rate

# %%
from sklearn.metrics import recall_score

score = dict()
score['Detection Rate'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            acc = recall_score(df_pred['Label'], df_pred[i].astype(int))
            score['Detection Rate'][i] = acc
            print(f'Recall-Binary-{i}: {acc}')
    else:
        for i in threshold_2:
            acc = recall_score(df_pred['Label'], df_pred[i].astype(int))
            score['Detection Rate'][i] = acc
            print(f'Recall-Floating-{i}: {acc}')
# Out:
# Recall-Binary-b_mean: 1.0
# Recall-Binary-b_iqr: 1.0
# Recall-Binary-b_zscore: 1.0
# Recall-Floating-f_mean: 0.9997512708504982
# Recall-Floating-f_iqr: 0.9997512708504982
# Recall-Floating-f_zscore: 0.9997512708504982

# %% [markdown]
# ### Confussion Matrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

for method in methods:
    if method == 'binary':
        for i in threshold:
            conf_matrix = confusion_matrix(df_pred['Label'], df_pred[i].astype(int))
            cm_display = ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels=['Benign', 'Anomaly'])
            cm_display.plot()
            plt.title(f'Binary - {i.strip()}')
            plt.show()
    else:
        for i in threshold_2:
            conf_matrix = confusion_matrix(df_pred['Label'], df_pred[i].astype(int))
            cm_display = ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels=['Benign', 'Anomaly'])
            cm_display.plot()
            plt.title(f'Floating - {i.strip()}')
            plt.show()

# %% [markdown]
# ### F2-Score

# %%
score['F2 Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i].astype(int)).ravel()
            f2 = ((1+2**2)*tp)/((1+2**2)*tp+2**2*fn+fp)
            score['F2 Score'][i] = f2
            print(f'F2-Binary-{i}: {f2}')
    else:
        for i in threshold_2:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i].astype(int)).ravel()
            f2 = ((1+2**2)*tp)/((1+2**2)*tp+2**2*fn+fp)
            score['F2 Score'][i] = f2
            print(f'F2-Floating-{i}: {f2}')
# Out:
# F2-Binary-b_mean: 0.9510763498728487
# F2-Binary-b_iqr: 0.933241063941528
# F2-Binary-b_zscore: 0.9350792448661276
# F2-Floating-f_mean: 0.9992215794944462
# F2-Floating-f_iqr: 0.9976590823416622
# F2-Floating-f_zscore: 0.9995228599803859

# %% [markdown]
# ### FPR Score

# %%
score['FPR Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i].astype(int)).ravel()
            fpr = fp/(fp+tn)
            score['FPR Score'][i] = fpr
            print(f'FPR-Binary-{i}: {fpr}')
    else:
        for i in threshold_2:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i].astype(int)).ravel()
            fpr = fp/(fp+tn)
            score['FPR Score'][i] = fpr
            print(f'FPR-Floating-{i}: {fpr}')
# Out:
# FPR-Binary-b_mean: 0.5801497273699529
# FPR-Binary-b_iqr: 0.8067745498536038
# FPR-Binary-b_zscore: 0.7830180409208058
# FPR-Floating-f_mean: 0.0065396146361134
# FPR-Floating-f_iqr: 0.024212353384645054
# FPR-Floating-f_zscore: 0.0031383137261777445

# %%
from sklearn.metrics import accuracy_score

score['Accuracy Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            acc = accuracy_score(df_pred['Label'], df_pred[i].astype(int))
            score['Accuracy Score'][i] = acc
            print(f'Accuracy-Binary-{i}: {acc}')
    else:
        for i in threshold_2:
            acc = accuracy_score(df_pred['Label'], df_pred[i].astype(int))
            score['Accuracy Score'][i] = acc
            print(f'Accuracy-Floating-{i}: {acc}')
# Out:
# Accuracy-Binary-b_mean: 0.8218007334765821
# Accuracy-Binary-b_iqr: 0.7521904669585494
# Accuracy-Binary-b_zscore: 0.7594875357448665
# Accuracy-Floating-f_mean: 0.9978189573000307
# Accuracy-Floating-f_iqr: 0.9923905843578849
# Accuracy-Floating-f_zscore: 0.9988637036797691

# %%
df_score = pd.DataFrame.from_dict(score)
df_score
# Out:
#           Detection Rate  F2 Score  FPR Score  Accuracy Score
# b_mean          1.000000  0.951076   0.580150        0.821801
# b_iqr           1.000000  0.933241   0.806775        0.752190
# b_zscore        1.000000  0.935079   0.783018        0.759488
# f_mean          0.999751  0.999222   0.006540        0.997819
# f_iqr           0.999751  0.997659   0.024212        0.992391
# f_zscore        0.999751  0.999523   0.003138        0.998864

# %%
df_score.to_excel('score_ftp_0.0.xlsx')

# %%
# %pip install openpyxl
