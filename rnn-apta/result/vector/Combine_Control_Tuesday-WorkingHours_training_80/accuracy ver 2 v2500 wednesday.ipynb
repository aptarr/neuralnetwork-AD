# %% [markdown]
# # Perhitungan Skor RNN-IDS

# %% [markdown]
# ## Import All Necessary Libraries

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Load All the Data

# %%
df_pred = pd.read_csv('/home/apta/neuralnetwork-AD/rnn-apta/results/vector/Combine_Control_Tuesday-WorkingHours_training_80/result-lstm-tcp80-hl2-seq4-do0.2-oov2500-Wednesday-WorkingHours_testing_80.csv', 
                      names=['id', 'binary_error', 'b_mean', 'b_iqr', 'b_zscore', 'floatin_error', 'f_mean', 'f_iqr', 'f_zscore'])

df_truth = pd.read_csv('/home/apta/CIC-IDS-2017/CSVs/TrafficLabelling/Wednesday-workingHours.pcap_ISCX.csv', 
                       encoding='ISO-8859-1')

# %%
df_pred.head()
# Out:
#                                          id  binary_error  b_mean  b_iqr  \
# 0    192.168.10.15-49451-13.107.4.50-80-tcp      0.113924       0      0
# 1  192.168.10.16-37380-91.189.88.161-80-tcp      0.127389       0      0
# 2    192.168.10.15-49451-13.107.4.50-80-tcp      0.110912       0      0
# 3  192.168.10.14-49463-23.194.182.93-80-tcp      0.313253       0      0
# 4   192.168.10.14-49467-165.254.0.90-80-tcp      0.148223       0      0
#
#    b_zscore  floatin_error  f_mean  f_iqr  f_zscore
# 0         1   83679.804487       0      0         1
# 1         1  110698.111111       0      0         1
# 2         1   84762.620000       0      0         1
# 3         0  136607.037037       0      0         1
# 4         1   67635.027572       0      0         1

# %%
df_truth.head()
# Out:
#                                   Flow ID      Source IP   Source Port  \
# 0  192.168.10.14-209.48.71.168-49459-80-6  192.168.10.14         49459
# 1  192.168.10.3-192.168.10.17-389-49453-6  192.168.10.17         49453
# 2   192.168.10.3-192.168.10.17-88-46124-6  192.168.10.17         46124
# 3  192.168.10.3-192.168.10.17-389-49454-6  192.168.10.17         49454
# 4   192.168.10.3-192.168.10.17-88-46126-6  192.168.10.17         46126
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0   209.48.71.168                 80          6  5/7/2017 8:42
# 1    192.168.10.3                389          6  5/7/2017 8:42
# 2    192.168.10.3                 88          6  5/7/2017 8:42
# 3    192.168.10.3                389          6  5/7/2017 8:42
# 4    192.168.10.3                 88          6  5/7/2017 8:42
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# 0           38308                   1                        1  ...
# 1             479                  11                        5  ...
# 2            1095                  10                        6  ...
# 3           15206                  17                       12  ...
# 4            1092                   9                        6  ...
#
#     min_seg_size_forward  Active Mean   Active Std   Active Max   Active Min  \
# 0                     20          0.0          0.0          0.0          0.0
# 1                     32          0.0          0.0          0.0          0.0
# 2                     32          0.0          0.0          0.0          0.0
# 3                     32          0.0          0.0          0.0          0.0
# 4                     32          0.0          0.0          0.0          0.0
#
#    Idle Mean   Idle Std   Idle Max   Idle Min   Label
# 0        0.0        0.0        0.0        0.0  BENIGN
# 1        0.0        0.0        0.0        0.0  BENIGN
# 2        0.0        0.0        0.0        0.0  BENIGN
# 3        0.0        0.0        0.0        0.0  BENIGN
# 4        0.0        0.0        0.0        0.0  BENIGN
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_pred[['b_iqr']].value_counts()
# Out:
# b_iqr
# 0        197573
# Name: count, dtype: int64

# %%
df_pred[['b_zscore']].value_counts()
# Out:
# b_zscore
# 0           148285
# 1            49288
# Name: count, dtype: int64

# %%
df_truth.isnull().sum()
# Out:
# Flow ID              0
#  Source IP           0
#  Source Port         0
#  Destination IP      0
#  Destination Port    0
#                     ..
# Idle Mean            0
#  Idle Std            0
#  Idle Max            0
#  Idle Min            0
#  Label               0
# Length: 85, dtype: int64

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Convert the type of the data

# %%
df_truth.columns = df_truth.columns.str.strip()  # remove leading/trailing spaces
df_truth.columns = df_truth.columns.str.replace(' ', '_')  # optional: make them easier to type

df_truth['Source_Port'] = pd.to_numeric(df_truth['Source_Port'], errors='coerce')
df_truth['Destination_Port'] = pd.to_numeric(df_truth['Destination_Port'], errors='coerce')

# Optionally: drop rows with NaN in these columns
df_truth.dropna(subset=['Source_Port', 'Destination_Port'], inplace=True)

# Filter to only include rows where either port is 80
df_truth = df_truth[(df_truth['Source_Port'] == 80) | (df_truth['Destination_Port'] == 80)]

# Now you can safely convert to int
df_truth['Source_Port'] = df_truth['Source_Port'].astype(int)
df_truth['Destination_Port'] = df_truth['Destination_Port'].astype(int)


df_truth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 325628 entries, 0 to 692697
# Data columns (total 85 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Flow_ID                      325628 non-null  object
#  1   Source_IP                    325628 non-null  object
#  2   Source_Port                  325628 non-null  int64
#  3   Destination_IP               325628 non-null  object
#  4   Destination_Port             325628 non-null  int64
#  5   Protocol                     325628 non-null  int64
#  6   Timestamp                    325628 non-null  object
#  7   Flow_Duration                325628 non-null  int64
#  8   Total_Fwd_Packets            325628 non-null  int64
#  9   Total_Backward_Packets       325628 non-null  int64
#  10  Total_Length_of_Fwd_Packets  325628 non-null  int64
#  11  Total_Length_of_Bwd_Packets  325628 non-null  float64
#  12  Fwd_Packet_Length_Max        325628 non-null  int64
#  13  Fwd_Packet_Length_Min        325628 non-null  int64
#  14  Fwd_Packet_Length_Mean       325628 non-null  float64
#  15  Fwd_Packet_Length_Std        325628 non-null  float64
#  16  Bwd_Packet_Length_Max        325628 non-null  int64
#  17  Bwd_Packet_Length_Min        325628 non-null  int64
#  18  Bwd_Packet_Length_Mean       325628 non-null  float64
#  19  Bwd_Packet_Length_Std        325628 non-null  float64
#  20  Flow_Bytes/s                 324670 non-null  float64
#  21  Flow_Packets/s               325628 non-null  float64
#  22  Flow_IAT_Mean                325628 non-null  float64
#  23  Flow_IAT_Std                 325628 non-null  float64
#  24  Flow_IAT_Max                 325628 non-null  float64
#  25  Flow_IAT_Min                 325628 non-null  float64
#  26  Fwd_IAT_Total                325628 non-null  float64
#  27  Fwd_IAT_Mean                 325628 non-null  float64
#  28  Fwd_IAT_Std                  325628 non-null  float64
#  29  Fwd_IAT_Max                  325628 non-null  float64
#  30  Fwd_IAT_Min                  325628 non-null  float64
#  31  Bwd_IAT_Total                325628 non-null  float64
#  32  Bwd_IAT_Mean                 325628 non-null  float64
#  33  Bwd_IAT_Std                  325628 non-null  float64
#  34  Bwd_IAT_Max                  325628 non-null  float64
#  35  Bwd_IAT_Min                  325628 non-null  float64
#  36  Fwd_PSH_Flags                325628 non-null  int64
#  37  Bwd_PSH_Flags                325628 non-null  int64
#  38  Fwd_URG_Flags                325628 non-null  int64
#  39  Bwd_URG_Flags                325628 non-null  int64
#  40  Fwd_Header_Length            325628 non-null  int64
#  41  Bwd_Header_Length            325628 non-null  int64
#  42  Fwd_Packets/s                325628 non-null  float64
#  43  Bwd_Packets/s                325628 non-null  float64
#  44  Min_Packet_Length            325628 non-null  int64
#  45  Max_Packet_Length            325628 non-null  int64
#  46  Packet_Length_Mean           325628 non-null  float64
#  47  Packet_Length_Std            325628 non-null  float64
#  48  Packet_Length_Variance       325628 non-null  float64
#  49  FIN_Flag_Count               325628 non-null  int64
#  50  SYN_Flag_Count               325628 non-null  int64
#  51  RST_Flag_Count               325628 non-null  int64
#  52  PSH_Flag_Count               325628 non-null  int64
#  53  ACK_Flag_Count               325628 non-null  int64
#  54  URG_Flag_Count               325628 non-null  int64
#  55  CWE_Flag_Count               325628 non-null  int64
#  56  ECE_Flag_Count               325628 non-null  int64
#  57  Down/Up_Ratio                325628 non-null  int64
#  58  Average_Packet_Size          325628 non-null  float64
#  59  Avg_Fwd_Segment_Size         325628 non-null  float64
#  60  Avg_Bwd_Segment_Size         325628 non-null  float64
#  61  Fwd_Header_Length.1          325628 non-null  int64
#  62  Fwd_Avg_Bytes/Bulk           325628 non-null  int64
#  63  Fwd_Avg_Packets/Bulk         325628 non-null  int64
#  64  Fwd_Avg_Bulk_Rate            325628 non-null  int64
#  65  Bwd_Avg_Bytes/Bulk           325628 non-null  int64
#  66  Bwd_Avg_Packets/Bulk         325628 non-null  int64
#  67  Bwd_Avg_Bulk_Rate            325628 non-null  int64
#  68  Subflow_Fwd_Packets          325628 non-null  int64
#  69  Subflow_Fwd_Bytes            325628 non-null  int64
#  70  Subflow_Bwd_Packets          325628 non-null  int64
#  71  Subflow_Bwd_Bytes            325628 non-null  int64
#  72  Init_Win_bytes_forward       325628 non-null  int64
#  73  Init_Win_bytes_backward      325628 non-null  int64
#  74  act_data_pkt_fwd             325628 non-null  int64
#  75  min_seg_size_forward         325628 non-null  int64
#  76  Active_Mean                  325628 non-null  float64
#  77  Active_Std                   325628 non-null  float64
#  78  Active_Max                   325628 non-null  float64
#  79  Active_Min                   325628 non-null  float64
#  80  Idle_Mean                    325628 non-null  float64
#  81  Idle_Std                     325628 non-null  float64
#  82  Idle_Max                     325628 non-null  float64
#  83  Idle_Min                     325628 non-null  float64
#  84  Label                        325628 non-null  object
# dtypes: float64(37), int64(43), object(5)
# memory usage: 213.7+ MB

# %%
df_truth['Label'].head()
# Out:
# 0     BENIGN
# 7     BENIGN
# 19    BENIGN
# 54    BENIGN
# 56    BENIGN
# Name: Label, dtype: object

# %%
df_truth['Source_Port'] = df_truth['Source_Port'].astype(str)
df_truth['Destination_Port'] = df_truth['Destination_Port'].astype(str)

df_truth['Protocol'] = pd.to_numeric(df_truth['Protocol'], errors='coerce')  
df_truth.dropna(subset=['Protocol'], inplace=True)                      
df_truth['Protocol'] = df_truth['Protocol'].astype(int).astype(str)         

protocol_map = {
    '6': 'tcp',
    '17': 'udp',
    '1': 'icmp',
    '0': 'other'  # fallback or unknown
}

# Convert 'Protocol' number to string using the mapping
def map_protocol(protocol):
    return protocol_map.get(protocol, 'other')

# Apply the conversion for 'Protocol' and concatenate the 'id'
df_truth['id'] = df_truth[['Source_IP', 'Source_Port', 'Destination_IP', 'Destination_Port', 'Protocol']]\
    .astype(str).apply(lambda row: "-".join([row[0], row[1], row[2], row[3], map_protocol(row[4])]), axis=1)
# Out:
# /tmp/ipykernel_362077/691346611.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   .astype(str).apply(lambda row: "-".join([row[0], row[1], row[2], row[3], map_protocol(row[4])]), axis=1)

# %% [markdown]
# ## Making Predictions

# %%
df_pred["id"]
# Out:
# 0           192.168.10.15-49451-13.107.4.50-80-tcp
# 1         192.168.10.16-37380-91.189.88.161-80-tcp
# 2           192.168.10.15-49451-13.107.4.50-80-tcp
# 3         192.168.10.14-49463-23.194.182.93-80-tcp
# 4          192.168.10.14-49467-165.254.0.90-80-tcp
#                             ...
# 197568    192.168.10.16-33590-199.59.88.242-80-tcp
# 197569    192.168.10.16-33594-199.59.88.242-80-tcp
# 197570    192.168.10.16-33588-199.59.88.242-80-tcp
# 197571    192.168.10.16-33596-199.59.88.242-80-tcp
# 197572    192.168.10.16-49086-54.192.36.242-80-tcp
# Name: id, Length: 197573, dtype: object

# %%
df_truth["id"]
# Out:
# 0         192.168.10.14-49459-209.48.71.168-80-tcp
# 7         192.168.10.16-37380-91.189.88.161-80-tcp
# 19         23.61.187.27-80-192.168.10.15-49441-tcp
# 54           192.168.10.15-49440-23.15.4.24-80-tcp
# 56        192.168.10.15-49447-165.254.0.106-80-tcp
#                             ...
# 692681       172.16.0.1-45758-192.168.10.50-80-tcp
# 692682      172.217.10.6-80-192.168.10.8-54901-tcp
# 692694      72.21.91.29-80-192.168.10.16-35450-tcp
# 692696       172.16.0.1-45756-192.168.10.50-80-tcp
# 692697    113.29.190.10-80-192.168.10.19-49346-tcp
# Name: id, Length: 325628, dtype: object

# %%
# Using boolean indexing to filter by the specific ID
count = df_truth[df_truth["id"] == "192.168.10.15-49451-13.107.4.50-80-tcp"].shape[0]

print(count)
# Out:
# 1

# %%
# Convert 'Label' column to numeric: BENIGN -> 0, other -> 1
df_truth['Label'] = df_truth['Label'].apply(lambda x: 0 if x == 'BENIGN' else 1)

# %%
# df_pred["Label"] = np.where(df_pred["id"].isin(df_truth["id"]), 1, 0)

df_pred = df_pred.merge(df_truth[['id', 'Label']], on='id', how='left')
df_pred = df_pred.dropna(subset=['Label'])

# %%
df_pred[df_pred['Label']==1]
# Out:
#                                             id  binary_error  b_mean  b_iqr  \
# 5673     172.16.0.1-53688-192.168.10.50-80-tcp      0.109649       0      0
# 5674     172.16.0.1-53688-192.168.10.50-80-tcp      0.109649       0      0
# 5675     172.16.0.1-53688-192.168.10.50-80-tcp      0.109649       0      0
# 5676     172.16.0.1-53688-192.168.10.50-80-tcp      0.109649       0      0
# 5677     172.16.0.1-53688-192.168.10.50-80-tcp      0.109649       0      0
# ...                                        ...           ...     ...    ...
# 3041051  172.16.0.1-42108-192.168.10.50-80-tcp      0.112676       0      0
# 3053152  172.16.0.1-49631-192.168.10.50-80-tcp      0.062384       0      0
# 3053153  172.16.0.1-49631-192.168.10.50-80-tcp      0.062384       0      0
# 3053157  172.16.0.1-49633-192.168.10.50-80-tcp      0.069597       0      0
# 3053158  172.16.0.1-49633-192.168.10.50-80-tcp      0.069597       0      0
#
#          b_zscore  floatin_error  f_mean  f_iqr  f_zscore  Label
# 5673            1   60268.178571       0      0         1      1
# 5674            1   60268.178571       0      0         1      1
# 5675            1   60268.178571       0      0         1      1
# 5676            1   60268.178571       0      0         1      1
# 5677            1   60268.178571       0      0         1      1
# ...           ...            ...     ...    ...       ...    ...
# 3041051         1   63621.612576       0      0         1      1
# 3053152         1   71440.627103       0      0         1      1
# 3053153         1   71440.627103       0      0         1      1
# 3053157         1  109754.906977       0      0         1      1
# 3053158         1  109754.906977       0      0         1      1
#
# [3015147 rows x 10 columns]

# %%
df_pred[df_pred['Label']==0]
# Out:
#                                                id  binary_error  b_mean  \
# 0          192.168.10.15-49451-13.107.4.50-80-tcp      0.113924       0
# 1        192.168.10.16-37380-91.189.88.161-80-tcp      0.127389       0
# 2          192.168.10.15-49451-13.107.4.50-80-tcp      0.110912       0
# 3        192.168.10.14-49463-23.194.182.93-80-tcp      0.313253       0
# 4         192.168.10.14-49467-165.254.0.90-80-tcp      0.148223       0
# ...                                           ...           ...     ...
# 3088286  192.168.10.16-33590-199.59.88.242-80-tcp      0.073477       0
# 3088287  192.168.10.16-33594-199.59.88.242-80-tcp      0.072193       0
# 3088288  192.168.10.16-33588-199.59.88.242-80-tcp      0.082180       0
# 3088289  192.168.10.16-33596-199.59.88.242-80-tcp      0.086587       0
# 3088290  192.168.10.16-49086-54.192.36.242-80-tcp      0.033860       0
#
#          b_iqr  b_zscore  floatin_error  f_mean  f_iqr  f_zscore  Label
# 0            0         1   83679.804487       0      0         1      0
# 1            0         1  110698.111111       0      0         1      0
# 2            0         1   84762.620000       0      0         1      0
# 3            0         0  136607.037037       0      0         1      0
# 4            0         1   67635.027572       0      0         1      0
# ...        ...       ...            ...     ...    ...       ...    ...
# 3088286      0         1   82007.381295       0      0         1      0
# 3088287      0         1   76941.909660       0      0         1      0
# 3088288      0         1   81991.042535       0      0         1      0
# 3088289      0         1   99323.105983       0      0         1      0
# 3088290      0         1   34955.594533       0      0         1      0
#
# [73144 rows x 10 columns]

# %%
df_pred
# Out:
#                                                id  binary_error  b_mean  \
# 0          192.168.10.15-49451-13.107.4.50-80-tcp      0.113924       0
# 1        192.168.10.16-37380-91.189.88.161-80-tcp      0.127389       0
# 2          192.168.10.15-49451-13.107.4.50-80-tcp      0.110912       0
# 3        192.168.10.14-49463-23.194.182.93-80-tcp      0.313253       0
# 4         192.168.10.14-49467-165.254.0.90-80-tcp      0.148223       0
# ...                                           ...           ...     ...
# 3088286  192.168.10.16-33590-199.59.88.242-80-tcp      0.073477       0
# 3088287  192.168.10.16-33594-199.59.88.242-80-tcp      0.072193       0
# 3088288  192.168.10.16-33588-199.59.88.242-80-tcp      0.082180       0
# 3088289  192.168.10.16-33596-199.59.88.242-80-tcp      0.086587       0
# 3088290  192.168.10.16-49086-54.192.36.242-80-tcp      0.033860       0
#
#          b_iqr  b_zscore  floatin_error  f_mean  f_iqr  f_zscore  Label
# 0            0         1   83679.804487       0      0         1      0
# 1            0         1  110698.111111       0      0         1      0
# 2            0         1   84762.620000       0      0         1      0
# 3            0         0  136607.037037       0      0         1      0
# 4            0         1   67635.027572       0      0         1      0
# ...        ...       ...            ...     ...    ...       ...    ...
# 3088286      0         1   82007.381295       0      0         1      0
# 3088287      0         1   76941.909660       0      0         1      0
# 3088288      0         1   81991.042535       0      0         1      0
# 3088289      0         1   99323.105983       0      0         1      0
# 3088290      0         1   34955.594533       0      0         1      0
#
# [3088291 rows x 10 columns]

# %%
df_pred[['Label']].value_counts()
# Out:
# Label
# 1        3015147
# 0          73144
# Name: count, dtype: int64

# %%
import os
# Define the directory path
dir_path = '../mcnemar/ftp'

# Check if the directory exists, and if not, create it
if not os.path.exists(dir_path):
    os.makedirs(dir_path)

df_temp = df_pred[['id', 'b_mean','b_iqr', 'b_zscore', 'f_zscore', 'f_mean','f_iqr' ]]
df_temp.to_csv(os.path.join(dir_path, 'pred_0.0.csv'))

# %% [markdown]
# ## Calculating Score

# %%
threshold = ['b_mean', 'b_iqr', 'b_zscore']
threshold_2 = ['f_mean', 'f_iqr', 'f_zscore']

methods = ['binary', 'floating']

# %%
df_pred[['b_zscore']]
# Out:
#          b_zscore
# 0               1
# 1               1
# 2               1
# 3               0
# 4               1
# ...           ...
# 3088286         1
# 3088287         1
# 3088288         1
# 3088289         1
# 3088290         1
#
# [3088291 rows x 1 columns]

# %% [markdown]
# ### Detection Rate

# %%
from sklearn.metrics import recall_score

score = dict()
score['Detection Rate'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            acc = recall_score(df_pred['Label'], df_pred[i].astype(int))
            score['Detection Rate'][i] = acc
            print(f'Recall-Binary-{i}: {acc}')
    else:
        for i in threshold_2:
            acc = recall_score(df_pred['Label'], df_pred[i].astype(int))
            score['Detection Rate'][i] = acc
            print(f'Recall-Floating-{i}: {acc}')
# Out:
# Recall-Binary-b_mean: 0.0
# Recall-Binary-b_iqr: 0.0
# Recall-Binary-b_zscore: 0.12097718618694213
# Recall-Floating-f_mean: 0.0
# Recall-Floating-f_iqr: 0.0
# Recall-Floating-f_zscore: 0.03353799997147734

# %% [markdown]
# ### Confussion Matrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

for method in methods:
    if method == 'binary':
        for i in threshold:
            conf_matrix = confusion_matrix(df_pred['Label'], df_pred[i].astype(int))
            cm_display = ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels=['Benign', 'Anomaly'])
            cm_display.plot()
            plt.title(f'Binary - {i.strip()}')
            plt.show()
    else:
        for i in threshold_2:
            conf_matrix = confusion_matrix(df_pred['Label'], df_pred[i].astype(int))
            cm_display = ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels=['Benign', 'Anomaly'])
            cm_display.plot()
            plt.title(f'Floating - {i.strip()}')
            plt.show()

# %% [markdown]
# ### F2-Score

# %%
score['F2 Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i].astype(int)).ravel()
            f2 = ((1+2**2)*tp)/((1+2**2)*tp+2**2*fn+fp)
            score['F2 Score'][i] = f2
            print(f'F2-Binary-{i}: {f2}')
    else:
        for i in threshold_2:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i].astype(int)).ravel()
            f2 = ((1+2**2)*tp)/((1+2**2)*tp+2**2*fn+fp)
            score['F2 Score'][i] = f2
            print(f'F2-Floating-{i}: {f2}')
# Out:
# F2-Binary-b_mean: 0.0
# F2-Binary-b_iqr: 0.0
# F2-Binary-b_zscore: 0.14593254498510605
# F2-Floating-f_mean: 0.0
# F2-Floating-f_iqr: 0.0
# F2-Floating-f_zscore: 0.04136130991033706

# %% [markdown]
# ### FPR Score

# %%
score['FPR Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i].astype(int)).ravel()
            fpr = fp/(fp+tn)
            score['FPR Score'][i] = fpr
            print(f'FPR-Binary-{i}: {fpr}')
    else:
        for i in threshold_2:
            tn, fp, fn, tp = confusion_matrix(df_pred['Label'], df_pred[i].astype(int)).ravel()
            fpr = fp/(fp+tn)
            score['FPR Score'][i] = fpr
            print(f'FPR-Floating-{i}: {fpr}')
# Out:
# FPR-Binary-b_mean: 0.0
# FPR-Binary-b_iqr: 0.0
# FPR-Binary-b_zscore: 0.989007984250246
# FPR-Floating-f_mean: 0.00010937329104232747
# FPR-Floating-f_iqr: 0.0
# FPR-Floating-f_zscore: 0.854697582850268

# %%
from sklearn.metrics import accuracy_score

score['Accuracy Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            acc = accuracy_score(df_pred['Label'], df_pred[i].astype(int))
            score['Accuracy Score'][i] = acc
            print(f'Accuracy-Binary-{i}: {acc}')
    else:
        for i in threshold_2:
            acc = accuracy_score(df_pred['Label'], df_pred[i].astype(int))
            score['Accuracy Score'][i] = acc
            print(f'Accuracy-Floating-{i}: {acc}')
# Out:
# Accuracy-Binary-b_mean: 0.02368429658992627
# Accuracy-Binary-b_iqr: 0.02368429658992627
# Accuracy-Binary-b_zscore: 0.11837226478981418
# Accuracy-Floating-f_mean: 0.02368170616046221
# Accuracy-Floating-f_iqr: 0.02368429658992627
# Accuracy-Floating-f_zscore: 0.03618506157612738

# %%
df_score = pd.DataFrame.from_dict(score)
df_score
# Out:
#           Detection Rate  F2 Score  FPR Score  Accuracy Score
# b_mean          0.000000  0.000000   0.000000        0.023684
# b_iqr           0.000000  0.000000   0.000000        0.023684
# b_zscore        0.120977  0.145933   0.989008        0.118372
# f_mean          0.000000  0.000000   0.000109        0.023682
# f_iqr           0.000000  0.000000   0.000000        0.023684
# f_zscore        0.033538  0.041361   0.854698        0.036185

# %%
df_score.to_excel('score_ftp_0.0.xlsx')

# %%
# %pip install openpyxl
