# %% [markdown]
# # Perhitungan Skor RNN-IDS

# %% [markdown]
# ## Import All Necessary Libraries

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Load All the Data

# %%
df_pred = pd.read_csv('./result-lstm-tcp25-hl2-seq3-do0.2-combined-00025.pcap.csv', names=['id', 'binary_error', 'b_mean', 'b_iqr', 'b_zscore', 'floatin_error', 'f_mean', 'f_iqr', 'f_zscore'])
df_truth = pd.read_csv('../NUSW-NB15_GT.csv')

# %%
df_pred.head()
# Out:
#                                          id  binary_error  b_mean  b_iqr  \
# 0  175.45.176.0-40755-149.171.126.18-25-tcp      0.920455       1      1
# 1  175.45.176.0-60595-149.171.126.17-25-tcp      0.916162       1      1
# 2  175.45.176.2-58472-149.171.126.17-25-tcp      0.923232       1      1
# 3  175.45.176.2-13352-149.171.126.13-25-tcp      0.413269       0      1
# 4   175.45.176.0-3844-149.171.126.12-25-tcp      0.353283       0      1
#
#    b_zscore  floatin_error  f_mean  f_iqr  f_zscore
# 0         1    1287.388426       1      1         1
# 1         1     896.662623       1      1         1
# 2         1    1195.973717       1      1         1
# 3         1     615.241987       0      0         0
# 4         1     448.998989       0      1         1

# %%
df_truth.head()
# Out:
#    Start time   Last time Attack category   Attack subcategory Protocol  \
# 0  1421927414  1421927416  Reconnaissance                 HTTP      tcp
# 1  1421927415  1421927415        Exploits     Unix 'r' Service      udp
# 2  1421927416  1421927416        Exploits              Browser      tcp
# 3  1421927417  1421927417        Exploits  Miscellaneous Batch      tcp
# 4  1421927418  1421927418        Exploits           Cisco IOS       tcp
#
#       Source IP  Source Port  Destination IP  Destination Port  \
# 0  175.45.176.0        13284  149.171.126.16                80
# 1  175.45.176.3        21223  149.171.126.18             32780
# 2  175.45.176.2        23357  149.171.126.16                80
# 3  175.45.176.2        13792  149.171.126.16              5555
# 4  175.45.176.2        26939  149.171.126.10                80
#
#                                          Attack Name  \
# 0  Domino Web Server Database Access: /doladmin.n...
# 1  Solaris rwalld Format String Vulnerability (ht...
# 2  Windows Metafile (WMF) SetAbortProc() Code Exe...
# 3  HP Data Protector Backup (https://strikecenter...
# 4  Cisco IOS HTTP Authentication Bypass Level 64 ...
#
#                                     Attack Reference  .
# 0                                                  -  .
# 1  CVE 2002-0573 (http://cve.mitre.org/cgi-bin/cv...  .
# 2  CVE 2005-4560 (http://cve.mitre.org/cgi-bin/cv...  .
# 3  CVE 2011-1729 (http://cve.mitre.org/cgi-bin/cv...  .
# 4  CVE 2001-0537 (http://cve.mitre.org/cgi-bin/cv...  .

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_pred[['b_iqr']].value_counts()
# Out:
# b_iqr
# 0        39000
# 1         5690
# Name: count, dtype: int64

# %%
df_pred[['b_zscore']].value_counts()
# Out:
# b_zscore
# 0           39656
# 1            5034
# Name: count, dtype: int64

# %%
df_truth.isnull().sum()
# Out:
# Start time                0
# Last time                 0
# Attack category           0
# Attack subcategory     4097
# Protocol                  0
# Source IP                 0
# Source Port               0
# Destination IP            0
# Destination Port          0
# Attack Name               1
# Attack Reference      50638
# .                         0
# dtype: int64

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Convert the type of the data

# %%
df_truth['Source Port'] = df_truth['Source Port'].astype(int)
df_truth['Destination Port'] =df_truth['Destination Port'].astype(int)
df_truth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174347 entries, 0 to 174346
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Start time          174347 non-null  int64
#  1   Last time           174347 non-null  int64
#  2   Attack category     174347 non-null  object
#  3   Attack subcategory  170250 non-null  object
#  4   Protocol            174347 non-null  object
#  5   Source IP           174347 non-null  object
#  6   Source Port         174347 non-null  int64
#  7   Destination IP      174347 non-null  object
#  8   Destination Port    174347 non-null  int64
#  9   Attack Name         174346 non-null  object
#  10  Attack Reference    123709 non-null  object
#  11  .                   174347 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 16.0+ MB

# %%
df_truth['Source Port'] = df_truth['Source Port'].astype(str)
df_truth['Destination Port'] =df_truth['Destination Port'].astype(str)
df_truth['id'] = df_truth[['Source IP', 'Source Port', 'Destination IP', 'Destination Port', 'Protocol']].apply("-".join, axis=1)

# %% [markdown]
# ## Making Predictions

# %%
df_pred["predicted"] = np.where(df_pred["id"].isin(df_truth["id"]), 1, 0)

# %%
df_pred[df_pred['predicted']==1]
# Out:
#                                              id  binary_error  b_mean  b_iqr  \
# 10     175.45.176.2-30357-149.171.126.16-25-tcp      0.658811       1      1
# 41     175.45.176.0-21014-149.171.126.15-25-tcp      0.964394       1      1
# 68     175.45.176.1-13963-149.171.126.13-25-tcp      0.343434       0      1
# 74     175.45.176.3-37532-149.171.126.19-25-tcp      0.922222       1      1
# 83     175.45.176.3-65113-149.171.126.16-25-tcp      0.914363       1      1
# ...                                         ...           ...     ...    ...
# 44133  175.45.176.0-40991-149.171.126.11-25-tcp      0.232828       0      1
# 44144  175.45.176.2-43215-149.171.126.15-25-tcp      0.969444       1      1
# 44150  175.45.176.2-30290-149.171.126.13-25-tcp      0.931061       1      1
# 44157  175.45.176.2-28720-149.171.126.15-25-tcp      0.657669       1      1
# 44158  175.45.176.3-46257-149.171.126.19-25-tcp      0.956818       1      1
#
#        b_zscore  floatin_error  f_mean  f_iqr  f_zscore  predicted
# 10            1    4209.237410       1      1         1          1
# 41            1    1669.809957       1      1         1          1
# 68            1     443.982815       0      1         1          1
# 74            1    1279.717210       1      1         1          1
# 83            1    1420.809601       1      1         1          1
# ...         ...            ...     ...    ...       ...        ...
# 44133         1     340.273187       0      1         1          1
# 44144         1    1685.776851       1      1         1          1
# 44150         1    2656.129896       1      1         1          1
# 44157         1     828.726601       1      1         1          1
# 44158         1    1104.274956       1      1         1          1
#
# [4057 rows x 10 columns]

# %%
df_pred[df_pred['predicted']==0]
# Out:
#                                              id  binary_error  b_mean  b_iqr  \
# 0      175.45.176.0-40755-149.171.126.18-25-tcp      0.920455       1      1
# 1      175.45.176.0-60595-149.171.126.17-25-tcp      0.916162       1      1
# 2      175.45.176.2-58472-149.171.126.17-25-tcp      0.923232       1      1
# 3      175.45.176.2-13352-149.171.126.13-25-tcp      0.413269       0      1
# 4       175.45.176.0-3844-149.171.126.12-25-tcp      0.353283       0      1
# ...                                         ...           ...     ...    ...
# 44685     59.166.0.9-21800-149.171.126.0-25-tcp      0.508081       0      0
# 44686      59.166.0.4-6591-149.171.126.6-25-tcp      0.516414       0      0
# 44687     59.166.0.1-41608-149.171.126.1-25-tcp      0.503164       0      0
# 44688     59.166.0.0-12790-149.171.126.2-25-tcp      0.516414       0      0
# 44689      59.166.0.5-7481-149.171.126.2-25-tcp      0.516414       0      0
#
#        b_zscore  floatin_error  f_mean  f_iqr  f_zscore  predicted
# 0             1    1287.388426       1      1         1          0
# 1             1     896.662623       1      1         1          0
# 2             1    1195.973717       1      1         1          0
# 3             1     615.241987       0      0         0          0
# 4             1     448.998989       0      1         1          0
# ...         ...            ...     ...    ...       ...        ...
# 44685         0     571.580996       0      0         0          0
# 44686         0     571.299975       0      0         0          0
# 44687         0     535.974000       0      0         0          0
# 44688         0     571.299975       0      0         0          0
# 44689         0     571.299975       0      0         0          0
#
# [40633 rows x 10 columns]

# %%
df_pred
# Out:
#                                              id  binary_error  b_mean  b_iqr  \
# 0      175.45.176.0-40755-149.171.126.18-25-tcp      0.920455       1      1
# 1      175.45.176.0-60595-149.171.126.17-25-tcp      0.916162       1      1
# 2      175.45.176.2-58472-149.171.126.17-25-tcp      0.923232       1      1
# 3      175.45.176.2-13352-149.171.126.13-25-tcp      0.413269       0      1
# 4       175.45.176.0-3844-149.171.126.12-25-tcp      0.353283       0      1
# ...                                         ...           ...     ...    ...
# 44685     59.166.0.9-21800-149.171.126.0-25-tcp      0.508081       0      0
# 44686      59.166.0.4-6591-149.171.126.6-25-tcp      0.516414       0      0
# 44687     59.166.0.1-41608-149.171.126.1-25-tcp      0.503164       0      0
# 44688     59.166.0.0-12790-149.171.126.2-25-tcp      0.516414       0      0
# 44689      59.166.0.5-7481-149.171.126.2-25-tcp      0.516414       0      0
#
#        b_zscore  floatin_error  f_mean  f_iqr  f_zscore  predicted
# 0             1    1287.388426       1      1         1          0
# 1             1     896.662623       1      1         1          0
# 2             1    1195.973717       1      1         1          0
# 3             1     615.241987       0      0         0          0
# 4             1     448.998989       0      1         1          0
# ...         ...            ...     ...    ...       ...        ...
# 44685         0     571.580996       0      0         0          0
# 44686         0     571.299975       0      0         0          0
# 44687         0     535.974000       0      0         0          0
# 44688         0     571.299975       0      0         0          0
# 44689         0     571.299975       0      0         0          0
#
# [44690 rows x 10 columns]

# %%
df_pred[['predicted']].value_counts()
# Out:
# predicted
# 0            40633
# 1             4057
# Name: count, dtype: int64

# %%
df_temp = df_pred[['id', 'b_mean','b_iqr', 'b_zscore', 'f_zscore', 'f_mean','f_iqr' ]]
df_temp.to_csv('../mcnemar/ftp/pred_0.0039.csv')

# %% [markdown]
# ## Calculating Score

# %%
threshold = ['b_mean', 'b_iqr', 'b_zscore']
threshold_2 = ['f_mean', 'f_iqr', 'f_zscore']

methods = ['binary', 'floating']

# %%
df_pred[['b_zscore']]
# Out:
#        b_zscore
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 44685         0
# 44686         0
# 44687         0
# 44688         0
# 44689         0
#
# [44690 rows x 1 columns]

# %% [markdown]
# ### Detection Rate

# %%
from sklearn.metrics import recall_score

score = dict()
score['Detection Rate'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            acc = recall_score(df_pred['predicted'], df_pred[i])
            score['Detection Rate'][i] = acc
            print(f'Recall-Binary-{i}: {acc}')
    else:
        for i in threshold_2:
            acc = recall_score(df_pred['predicted'], df_pred[i])
            score['Detection Rate'][i] = acc
            print(f'Recall-Floating-{i}: {acc}')
# Out:
# Recall-Binary-b_mean: 0.769780626078383
# Recall-Binary-b_iqr: 0.9723933941335963
# Recall-Binary-b_zscore: 0.9674636430860242
# Recall-Floating-f_mean: 0.7525264974118807
# Recall-Floating-f_iqr: 0.9317229479911264
# Recall-Floating-f_zscore: 0.9048558047818586

# %% [markdown]
# ### Confussion Matrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

for method in methods:
    if method == 'binary':
        for i in threshold:
            conf_matrix = confusion_matrix(df_pred['predicted'], df_pred[i])
            cm_display = ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels = [False, True])
            cm_display.plot()
            plt.title(f'Binary - {i.strip()}')
            plt.show()
    else:
        for i in threshold_2:
            conf_matrix = confusion_matrix(df_pred['predicted'], df_pred[i])
            cm_display = ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels = [False, True])
            cm_display.plot()
            plt.title(f'Floating - {i.strip()}')
            plt.show()

# %% [markdown]
# ### F2-Score

# %%
score['F2 Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            tn, fp, fn, tp = confusion_matrix(df_pred['predicted'], df_pred[i]).ravel()
            f2 = ((1+2**2)*tp)/((1+2**2)*tp+2**2*fn+fp)
            score['F2 Score'][i] = f2
            print(f'F2-Binary-{i}: {f2}')
    else:
        for i in threshold_2:
            tn, fp, fn, tp = confusion_matrix(df_pred['predicted'], df_pred[i]).ravel()
            f2 = ((1+2**2)*tp)/((1+2**2)*tp+2**2*fn+fp)
            score['F2 Score'][i] = f2
            print(f'F2-Floating-{i}: {f2}')
# Out:
# F2-Binary-b_mean: 0.7817271589486858
# F2-Binary-b_iqr: 0.8999452504790583
# F2-Binary-b_zscore: 0.9230081836139592
# F2-Floating-f_mean: 0.7696379953615005
# F2-Floating-f_iqr: 0.9064313462184068
# F2-Floating-f_zscore: 0.8934047213433925

# %% [markdown]
# ### FPR Score

# %%
score['FPR Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            tn, fp, fn, tp = confusion_matrix(df_pred['predicted'], df_pred[i]).ravel()
            fpr = fp/(fp+tn)
            score['FPR Score'][i] = fpr
            print(f'FPR-Binary-{i}: {fpr}')
    else:
        for i in threshold_2:
            tn, fp, fn, tp = confusion_matrix(df_pred['predicted'], df_pred[i]).ravel()
            fpr = fp/(fp+tn)
            score['FPR Score'][i] = fpr
            print(f'FPR-Floating-{i}: {fpr}')
# Out:
# FPR-Binary-b_mean: 0.015356975857061994
# FPR-Binary-b_iqr: 0.04294538921566215
# FPR-Binary-b_zscore: 0.027293086899810498
# FPR-Floating-f_mean: 0.013609627642556544
# FPR-Floating-f_iqr: 0.020746683729973174
# FPR-Floating-f_zscore: 0.01589840769817636

# %%
from sklearn.metrics import accuracy_score

score['Accuracy Score'] = dict()
for method in methods:
    if method == 'binary':
        for i in threshold:
            acc = accuracy_score(df_pred['predicted'], df_pred[i])
            score['Accuracy Score'][i] = acc
            print(f'Accuracy-Binary-{i}: {acc}')
    else:
        for i in threshold_2:
            acc = accuracy_score(df_pred['predicted'], df_pred[i])
            score['Accuracy Score'][i] = acc
            print(f'Accuracy-Floating-{i}: {acc}')
# Out:
# Accuracy-Binary-b_mean: 0.9651376146788991
# Accuracy-Binary-b_iqr: 0.9584470798836429
# Accuracy-Binary-b_zscore: 0.9722309241441038
# Accuracy-Floating-f_mean: 0.9651599910494518
# Accuracy-Floating-f_iqr: 0.9749384649809801
# Accuracy-Floating-f_zscore: 0.9769075855896173

# %%
df_score = pd.DataFrame.from_dict(score)
df_score
# Out:
#           Detection Rate  F2 Score  FPR Score  Accuracy Score
# b_mean          0.769781  0.781727   0.015357        0.965138
# b_iqr           0.972393  0.899945   0.042945        0.958447
# b_zscore        0.967464  0.923008   0.027293        0.972231
# f_mean          0.752526  0.769638   0.013610        0.965160
# f_iqr           0.931723  0.906431   0.020747        0.974938
# f_zscore        0.904856  0.893405   0.015898        0.976908

# %%
df_score.to_excel('score_smtp_0.003.xlsx')
